# %% [markdown]
# <a href="https://colab.research.google.com/github/anieruth007/CSE3040_DATA_SCIENCE_PROJECT/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv("Data.csv")
data
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %%
#scatter plot for the given data
plt.scatter(data['SAT'],data['GPA'])
plt.show()

# %%
#heatmap for the dataset with readings in it
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn import linear_model
regress = linear_model.LinearRegression()

train_x = np.asanyarray(data[['SAT']])
train_y = np.asanyarray(data[['GPA']])
#print(train_x)
#print(train_y)

regress.fit (train_x,train_y)
# The coefficients
print ('Coefficients: ', regress.coef_)
print ('Intercept: ',regress.intercept_)

regress1 = linear_model.LinearRegression()
train_x1 = np.asanyarray(data[['SAT']])
train_y1 = np.asanyarray(data[['GPA']])
#print(train_x)
#print(train_y)

regress1.fit (train_x1,train_y1)
# The coefficients
print ('Coefficients: ', regress1.coef_)
print ('Intercept: ',regress1.intercept_)
# Out:
# Coefficients:  [[0.00165569]]
# Intercept:  [0.2750403]
# Coefficients:  [[0.00165569]]
# Intercept:  [0.2750403]

# %%
plt.scatter(data.SAT, data.GPA,  color='blue',label="Actual")
plt.plot(train_x, regress.coef_[0][0]*train_x + regress.intercept_[0], '-r',label="Predicted")
plt.title("Placement plot")
plt.legend()
plt.xlabel("SAT")
plt.ylabel("GPA")
plt.show()

# %%
y_predicted = regress.predict(train_x)
for i in range(0,len(train_x)):
    print(train_y[i],y_predicted[i])
data['Predicted'] = y_predicted
print(y_predicted)
print(data.head())
# Out:
# [2.4] [3.11288962]
# [2.52] [3.03010522]
# [2.54] [3.18905127]
# [2.74] [3.06487466]
# [2.83] [3.07812017]
# [2.91] [3.04003934]
# [3.] [3.19567402]
# [3.] [3.19567402]
# [3.01] [3.24203329]
# [3.01] [3.33806319]
# [3.02] [3.14765907]
# [3.07] [3.21388659]
# [3.08] [3.14765907]
# [3.08] [3.10957824]
# [3.12] [3.21057521]
# [3.17] [3.37448833]
# [3.17] [3.18077283]
# [3.17] [3.0466621]
# [3.17] [3.32481769]
# [3.19] [3.23209916]
# [3.19] [3.19070696]
# [3.19] [3.12613512]
# [3.2] [3.02844953]
# [3.21] [3.06818604]
# [3.24] [3.54336851]
# [3.28] [3.29832668]
# [3.28] [3.23375485]
# [3.28] [3.29004824]
# [3.28] [3.61953016]
# [3.28] [3.24534466]
# [3.28] [3.20395246]
# [3.28] [3.47714099]
# [3.29] [3.21388659]
# [3.29] [3.34634163]
# [3.29] [3.38773383]
# [3.31] [3.3364075]
# [3.32] [3.26852429]
# [3.34] [3.51025475]
# [3.37] [3.21719796]
# [3.37] [3.30660512]
# [3.37] [3.36289851]
# [3.38] [3.33806319]
# [3.38] [3.53012301]
# [3.39] [3.09302136]
# [3.39] [3.56985952]
# ...

# %%
#finding new y values with y=mx+c with coefficent and intercept
y_predicted = regress.predict([[1700]])
print(y_predicted)
# Out:
# [[3.08970998]]

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(train_y, y_predicted))
print('Mean Squared Error:', metrics.mean_squared_error(train_y, y_predicted))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(train_y, y_predicted)))
# Out:
# Mean Absolute Error: 0.15496879012561524
# Mean Squared Error: 0.04330086666167266
# Root Mean Squared Error: 0.2080886029115306
